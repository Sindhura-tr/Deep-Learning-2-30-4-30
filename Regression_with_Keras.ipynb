# %% [markdown]
# <a href="https://colab.research.google.com/github/Sindhura-tr/Deep-Learning-2-30-4-30/blob/main/Regression_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Regression with Keras

# %% [markdown]
# ## Switch from CPU to GPU. Always work on GPU runtime
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Data Ingestion

# %%
path = "https://raw.githubusercontent.com/Sindhura-tr/Datasets/refs/heads/main/PowerPlant.csv"
import pandas as pd
df = pd.read_csv(path)
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
# ## Perform the basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
df.shape
# Out:
# (9568, 5)

# %%
df.columns
# Out:
# Index(['AT', 'V', 'AP', 'RH', 'PE'], dtype='object')

# %% [markdown]
# ## check for missing data/duplicated rows

# %%
df.isna().sum()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(41)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Separate X and Y features

# %%
X = df.drop(columns=["PE"])
Y = df[["PE"]]

# %%
X.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
Y.head()
# Out:
#        PE
# 0  480.48
# 1  445.75
# 2  438.76
# 3  453.09
# 4  464.43

# %% [markdown]
# ## Data Preprocessing and Data cleaning

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
num_pipe = make_pipeline(SimpleImputer(strategy="mean"),StandardScaler()).set_output(transform="pandas")

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#          AT         V        AP        RH
# 0 -1.520448 -1.066041 -0.403535  1.141599
# 1  0.534897  0.330813 -0.309262  0.059223
# 2  1.354348  0.205475 -1.024725 -2.151400
# 3 -0.079020 -0.362884 -1.012941  0.236538
# 4 -1.055645 -1.074713  0.655349  1.633837

# %% [markdown]
# ## Perform train test split

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,Y,train_size=0.75,random_state=42)

# %%
xtrain.head()
# Out:
#             AT         V        AP        RH
# 1845 -0.886381 -0.795657  0.961736  0.845161
# 8505  0.939249  0.960659 -1.268824 -0.564462
# 8152 -0.957579 -0.966717  0.729421  0.563784
# 5023  0.143978  0.439598  0.983620  0.489161
# 1744 -1.214161 -0.967505 -2.257003  1.596868

# %%
xtest.head()
# Out:
#             AT         V        AP        RH
# 1087  1.827212  1.120683 -0.125767 -1.414069
# 6319 -1.501641 -1.244984  0.044260 -0.467246
# 8052 -1.465370 -1.418408  0.399466 -1.082031
# 9524  0.150695  0.648495  0.731104 -0.002393
# 4463 -0.036032  1.128565 -0.361449  1.586599

# %%
ytrain.head()
# Out:
#           PE
# 1845  469.02
# 8505  436.65
# 8152  469.18
# 5023  445.18
# 1744  472.41

# %%
ytest.head()
# Out:
#           PE
# 1087  429.38
# 6319  485.29
# 8052  480.40
# 9524  452.30
# 4463  446.47

# %% [markdown]
# ## Model building with Keras

# %%
from keras.models import Sequential
from keras.layers import Input,Dense

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
xtrain.shape
# Out:
# (7145, 4)

# %%
# Column shape/features shape
xtrain.shape[1]
# Out:
# 4

# %%
# Intialize the model
model = Sequential()

# Add the Input layer by providing features as Input
model.add(Input(shape=(xtrain.shape[1],)))

# Add the Dense layer - hidden layer 1
model.add(Dense(units=8,activation="relu"))

# Add another hidden layer 2
model.add(Dense(units=4,activation="relu"))

# Add the output layer
model.add(Dense(units=1,activation="linear"))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam",loss="mse",metrics=["mae"])

# %% [markdown]
#     Deep Learning
#     train test split
#     train model, further splitting will happens
#     train data is further divided into training and validation
#
#     Model will be compared with trianing scores and validated scores

# %% [markdown]
# ## Epoch: one complete pass of forward propagation and backpropagation

# %%
hist = model.fit(xtrain,ytrain,validation_split=0.2,epochs=100)
# Out:
# Epoch 1/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss:
100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 23.0762 - mae: 3.8068 - val_loss: 21.2063 - val_mae: 3.5737
# Epoch 64/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.8012 - mae: 3.6877 - val_loss: 21.4351 - val_mae: 3.5901
# Epoch 65/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.6263 - mae: 3.6342 - val_loss: 21.1789 - val_mae: 3.5925
# Epoch 66/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.0675 - mae: 3.6761 - val_loss: 21.0995 - val_mae: 3.5712
# Epoch 67/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.5309 - mae: 3.6015 - val_loss: 21.9145 - val_mae: 3.6398
# Epoch 68/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.0085 - mae: 3.6777 - val_loss: 22.0560 - val_mae: 3.6791
# Epoch 69/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.3047 - mae: 3.6831 - val_loss: 21.4214 - val_mae: 3.6160
# Epoch 70/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.2692 - mae: 3.6422 - val_loss: 21.0821 - val_mae: 3.5752
# Epoch 71/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.0964 - mae: 3.5720 - val_loss: 21.0791 - val_mae: 3.5558
# Epoch 72/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.1272 - mae: 3.6358 - val_loss: 21.4628 - val_mae: 3.6080
# Epoch 73/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.0736 - mae: 3.6197 - val_loss: 21.0962 - val_mae: 3.5887
# Epoch 74/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.6048 - mae: 3.6412 - val_loss: 21.0524 - val_mae: 3.5607
# Epoch 75/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.8225 - mae: 3.6540 - val_loss: 21.5303 - val_mae: 3.6027
# Epoch 76/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7223 - mae: 3.6037 - val_loss: 20.9431 - val_mae: 3.5505
# Epoch 77/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.7409 - mae: 3.6937 - val_loss: 21.0273 - val_mae: 3.5784
# Epoch 78/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.5581 - mae: 3.6198 - val_loss: 21.1901 - val_mae: 3.6035
# Epoch 79/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.3233 - mae: 3.6077 - val_loss: 21.0019 - val_mae: 3.5697
# Epoch 80/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.8640 - mae: 3.6227 - val_loss: 21.7767 - val_mae: 3.6242
# Epoch 81/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.0932 - mae: 3.5977 - val_loss: 21.2064 - val_mae: 3.5914
# Epoch 82/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.4778 - mae: 3.6695 - val_loss: 20.8868 - val_mae: 3.5571
# Epoch 83/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.3970 - mae: 3.6517 - val_loss: 21.1849 - val_mae: 3.5807
# Epoch 84/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.9016 - mae: 3.6378 - val_loss: 21.0852 - val_mae: 3.5785
# Epoch 85/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.6548 - mae: 3.7057 - val_loss: 21.2297 - val_mae: 3.6064
# Epoch 86/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.9887 - mae: 3.6545 - val_loss: 21.7097 - val_mae: 3.6366
# Epoch 87/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 22.3069 - mae: 3.6924 - val_loss: 21.6933 - val_mae: 3.6570
# Epoch 88/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.8435 - mae: 3.6398 - val_loss: 21.2241 - val_mae: 3.5977
# Epoch 89/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.1227 - mae: 3.7124 - val_loss: 21.2894 - val_mae: 3.5928
# Epoch 90/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.4287 - mae: 3.6000 - val_loss: 21.1263 - val_mae: 3.5575
# Epoch 91/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7230 - mae: 3.6279 - val_loss: 20.8699 - val_mae: 3.5496
# Epoch 92/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.0853 - mae: 3.6531 - val_loss: 21.8599 - val_mae: 3.6674
# Epoch 93/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.9629 - mae: 3.6477 - val_loss: 21.0257 - val_mae: 3.5828
# Epoch 94/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.8000 - mae: 3.5570 - val_loss: 21.9261 - val_mae: 3.6790
# Epoch 95/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.2161 - mae: 3.6892 - val_loss: 21.4771 - val_mae: 3.6033
# Epoch 96/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.3868 - mae: 3.6319 - val_loss: 21.4394 - val_mae: 3.6347
# Epoch 97/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.5017 - mae: 3.6462 - val_loss: 21.3078 - val_mae: 3.5732
# Epoch 98/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.9391 - mae: 3.5778 - val_loss: 21.5049 - val_mae: 3.6362
# Epoch 99/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.7637 - mae: 3.6559 - val_loss: 21.0158 - val_mae: 3.5600
# Epoch 100/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.0802 - mae: 3.6680 - val_loss: 21.1806 - val_mae: 3.5742

# %% [markdown]
# ## Evaluate the model

# %%
model.evaluate(xtrain,ytrain)
# Out:
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.5955 - mae: 3.6165
# [20.890531539916992, 3.605670690536499]

# %%
model.evaluate(xtest,ytest)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 19.8614 - mae: 3.5585
# [21.08271026611328, 3.6216018199920654]

# %% [markdown]
# ## Learning Curve

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history["loss"],label="Training Loss")
plt.plot(hist.history["val_loss"],label="Validation Loss")
plt.xlabel("Number of Epochs")
plt.ylabel("Loss-MSE")
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluate the model using testing data

# %%
ypred_test = model.predict(xtest)
ypred_test
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# array([[426.72852],
#        [481.7546 ],
#        [483.3625 ],
#        ...,
#        [453.88647],
#        [476.7451 ],
#        [455.63947]], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
def evaluate_model(model,xdata,ydata):
  ypred=model.predict(xdata)

  MSE = mean_squared_error(ydata,ypred)
  MAE = mean_absolute_error(ydata,ypred)
  R2 = r2_score(ydata,ypred)

  print(f"MSE: {MSE}")
  print(f"MAE:{MAE}")
  print(f"R2-score: {R2}")

# %%
evaluate_model(model,xtrain,ytrain)
# Out:
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE: 20.89053726196289
# MAE:3.6056699752807617
# R2-score: 0.9273615479469299

# %%
evaluate_model(model,xtest,ytest)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE: 21.08271026611328
# MAE:3.6216013431549072
# R2-score: 0.9293158054351807

# %% [markdown]
# ## Save the model

# %%
model.save("PowerplantPredictions.keras")

# %% [markdown]
# ## Above model provides ~93% r2 score in test data. Let's consider this model for final predictions

# %% [markdown]
# ## Load the keras models

# %%
from keras.models import load_model

# %%
m = load_model("/content/PowerplantPredictions.keras")

# %%
m.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 245 (984.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 164 (660.00 B)

# %%
path2 = "https://raw.githubusercontent.com/Sindhura-tr/Datasets/refs/heads/main/PowerPlantTest.csv"
xnew = pd.read_csv(path2)
xnew
# Out:
#    AT     V      AP    RH
# 0  25  51.5  1000.1  57.0
# 1  32  41.0  1051.1  80.0
# 2  28   NaN  1010.2   NaN

# %%
xnew_pre = num_pipe.transform(xnew)
xnew_pre.head()
# Out:
#          AT         V        AP        RH
# 0  0.717594 -0.220203 -2.211551 -1.118316
# 1  1.657948 -1.047911  6.373998  0.456299
# 2  1.120603  0.000000 -0.511275  0.000000

# %%
PE_preds = m.predict(xnew_pre)
PE_preds = PE_preds.round(2)
PE_preds
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# array([[445.31],
#        [443.54],
#        [437.53]], dtype=float32)

# %% [markdown]
# ## Save the data to dataframe and then save the results to csv file

# %%
xnew["PE Predicted"] = PE_preds

# %%
xnew.columns
# Out:
# Index(['AT', 'V', 'AP', 'RH', 'PE Predicted'], dtype='object')

# %%
xnew["PE Predicted"] = xnew["PE Predicted"].round(2)
xnew
# Out:
#    AT     V      AP    RH  PE Predicted
# 0  25  51.5  1000.1  57.0    445.309998
# 1  32  41.0  1051.1  80.0    443.540009
# 2  28   NaN  1010.2   NaN    437.529999
